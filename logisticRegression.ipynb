# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriya987/LogisticRegression/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
# %matplotlib inline
digits=load_digits()

# %%
print('Image data shape',digits.data.shape)
print('Label data shape',digits.target.shape)
# Out:
# Image data shape (1797, 64)
# Label data shape (1797,)

# %%
plt.figure(figsize=(20,4))
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
for index,(image,label) in enumerate(zip(digits.data[0:5],digits.target[0:5])):
    plt.subplot(1,5,index+1)
    plt.imshow(np.reshape(image,(8,8)),cmap=plt.cm.gray)
    plt.title('%i\n'%label,fontsize=20)

# %%
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.25,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1347, 64)
# (450, 64)
# (1347,)
# (450,)

# %%
from sklearn.linear_model import LogisticRegression
logisticregressor=LogisticRegression()
logisticregressor.fit(x_train,y_train)
logisticregressor.predict(x_test[0:10])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([2, 8, 2, 6, 6, 7, 1, 9, 8, 5])

# %%
score=logisticregressor.score(x_test,y_test)
print(score)
# Out:
# 0.9511111111111111

# %%
plt.figure(figsize=(9,9))
sns.heatmap(metrics.confusion_matrix(y_test,logisticregressor.predict(x_test)),annot=True,fmt='.3f',linewidths=.5,square=True)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title='Accuracy Score:{0}'.format(score)
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score:0.9511111111111111')
